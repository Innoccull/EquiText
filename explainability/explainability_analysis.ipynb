# %% [markdown]
# # Example

# %% [markdown]
# https://medium.com/@ycouble/explaining-spacy-models-with-shap-1ec55c33bd65

# %%
import spacy

textcat_spacy = spacy.load(".\model-best\model-best")
tokenizer_spacy = spacy.tokenizer.Tokenizer(textcat_spacy.vocab)
classes = list(textcat_spacy.get_pipe("textcat").labels)

# Define a function to predict
def predict(texts):

    # convert texts to bare strings
    texts = [str(text) for text in texts]

    results = []
    for doc in textcat_spacy.pipe(texts):
        # results.append([{'label': cat, 'score': doc.cats[cat]} for cat in doc.cats])
        results.append([doc.cats[cat] for cat in classes])

    print(results)
    return results

# Create a function to create a transformers-like tokenizer to match shap's expectations
def tok_wrapper(text, return_offsets_mapping=False):
    doc = tokenizer_spacy(text)
    out = {"input_ids": [tok.norm for tok in doc]}
    if return_offsets_mapping:
        out["offset_mapping"] = [(tok.idx, tok.idx + len(tok)) for tok in doc]
    return out

# %%
import shap
# Create the Shap Explainer
# - predict is the "model" function, adapted to a transformers-like model
# - masker is the masker used by shap, which relies on a transformers-like tokenizer
# - algorithm is set to permutation, which is the one used for transformers models
# - output_names are the classes (although it is not propagated to the permutation explainer currently, which is why plots do not have the labels)
# - max_evals is set to a high number to reduce the probability of cases where the explainer fails because there are too many tokens
explainer = shap.Explainer(
    predict,
    masker=shap.maskers.Text(tok_wrapper),
    algorithm="permutation",
    output_names=classes,
    max_evals=1500,
)

# %%
import pandas as pd
dataset = pd.read_csv(".\data\\reddit_data.csv")["text"].tolist()
dataset[0]
# Out:
# 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'

# %%
shap_values = explainer(dataset[:1])
shap_values.output_names = classes
# Out:
# ['...' '...and ...' '...MLB, ...and ...' '...MLB, NFL, and ...'
#  '...but ...MLB, NFL, and ...']
# ['...', '...and ...', '...MLB, ...and ...', '...MLB, NFL, and ...', '...but ...MLB, NFL, and ...']
# ['...but ...in MLB, NFL, and ...'
#  '...but ...interested in MLB, NFL, and ...'
#  '...but ...also interested in MLB, NFL, and ...'
#  '...but am also interested in MLB, NFL, and ...'
#  '...but am also interested in MLB, NFL, and ...and ...']
# ['...but ...in MLB, NFL, and ...', '...but ...interested in MLB, NFL, and ...', '...but ...also interested in MLB, NFL, and ...', '...but am also interested in MLB, NFL, and ...', '...but am also interested in MLB, NFL, and ...and ...']
# ['...but am also interested in MLB, NFL, and ...and b-ball.'
#  '...but am also interested in MLB, NFL, and NCAA ...and b-ball.'
#  '...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['...but am also interested in MLB, NFL, and ...and b-ball.', '...but am also interested in MLB, NFL, and NCAA ...and b-ball.', '...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['...specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...I’m ...specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...this? ...I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...tracks this? ...I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['...specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...I’m ...specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...this? ...I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...tracks this? ...I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['...tracks this? ...now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...of ...tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...of an ...tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...of an ...that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['...tracks this? ...now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...of ...tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...of an ...tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...of an ...that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['...of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...direction. ...of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...direction. Does ...of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...direction. Does anyone ...of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['...of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...direction. ...of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...direction. Does ...of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...direction. Does anyone ...of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['...for ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  '...for datasets ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m ...for datasets ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['...for ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', '...for datasets ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m ...for datasets ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or ...or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or ...base, or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or ...fan base, or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or ...quantifies fan base, or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or ...that quantifies fan base, or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or ...or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or ...base, or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or ...fan base, or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or ...quantifies fan base, or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or ...that quantifies fan base, or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api ...that quantifies fan base, or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or ...bettors’ ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ ...regarding ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api ...that quantifies fan base, or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or ...bettors’ ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ ...regarding ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, ...NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in ...NFL, ...NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in ...NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...am also interested in ...NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...am also interested ...NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, ...NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in ...NFL, ...NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in ...NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...am also interested in ...NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...am also interested ...NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...am also ...NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...am ...NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...NCAA f-ball ...b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...NCAA f-ball ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...am also ...NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...am ...NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...NCAA f-ball ...b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...NCAA f-ball ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...f-ball ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...f-ball ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now ...looking ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks ...For now ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...For now ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...For ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now ...looking ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks ...For now ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...For now ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...For ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know ...an API that ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know ...API that ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know ...API ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know ...an API that ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know ...API that ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know ...API ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...Does anyone know ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...anyone know ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...know ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  'I’m looking ...datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...Does anyone know ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...anyone know ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...know ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', 'I’m looking ...datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['I’m looking ...or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...looking ...or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...api source that quantifies fan base, ...preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['I’m looking ...or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', '...looking ...or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', '...or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', '...api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', '...api source that quantifies fan base, ...preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['...api source that quantifies fan ...preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...api source that quantifies ...preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...api source that ...preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...api source ...preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...source ...preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['...api source that quantifies fan ...preferably, bettors’ sentiment regarding a team’s performance or ...', '...api source that quantifies ...preferably, bettors’ sentiment regarding a team’s performance or ...', '...api source that ...preferably, bettors’ sentiment regarding a team’s performance or ...', '...api source ...preferably, bettors’ sentiment regarding a team’s performance or ...', '...source ...preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['...preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...preferably, ...sentiment regarding a team’s performance or ...'
#  '...sentiment regarding a team’s performance or ...'
#  '...sentiment ...a team’s performance or ...'
#  '...a team’s performance or ...']
# ['...preferably, bettors’ sentiment regarding a team’s performance or ...', '...preferably, ...sentiment regarding a team’s performance or ...', '...sentiment regarding a team’s performance or ...', '...sentiment ...a team’s performance or ...', '...a team’s performance or ...']
# ['...team’s performance or ...' '...performance or ...' '...or ...' '...']
# ['...team’s performance or ...', '...performance or ...', '...or ...', '...']
# ['...' '...or ...' '...a ...or ...' '...a team’s ...or ...'
#  '...a team’s performance or ...']
# ['...', '...or ...', '...a ...or ...', '...a team’s ...or ...', '...a team’s performance or ...']
# ['...regarding a team’s performance or ...'
#  '...sentiment regarding a team’s performance or ...'
#  '...preferably, ...sentiment regarding a team’s performance or ...'
#  '...preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...or preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['...regarding a team’s performance or ...', '...sentiment regarding a team’s performance or ...', '...preferably, ...sentiment regarding a team’s performance or ...', '...preferably, bettors’ sentiment regarding a team’s performance or ...', '...or preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['...fan ...or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...api ...that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['...fan ...or preferably, bettors’ sentiment regarding a team’s performance or ...', '...fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', '...quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', '...that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', '...api ...that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['...api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...looking ...or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  'I’m looking ...or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  'I’m looking for ...or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['...api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', '...or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', '...looking ...or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', 'I’m looking ...or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', 'I’m looking for ...or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...API ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...API that ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...an API that ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...of an API that ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...API ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...API that ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...an API that ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...of an API that ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...anyone ...of an API that ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...anyone know of an API that ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. ...anyone know of an API that ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...NBA, ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...anyone ...of an API that ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...anyone know of an API that ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. ...anyone know of an API that ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...NBA, ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...for NBA, ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...specifically for NBA, ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...I’m ...specifically for NBA, ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...I’m looking specifically for NBA, ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...For ...I’m looking specifically for NBA, ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...for NBA, ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...specifically for NBA, ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...I’m ...specifically for NBA, ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...I’m looking specifically for NBA, ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...For ...I’m looking specifically for NBA, ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...For now I’m looking specifically for NBA, ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...this? For now I’m looking specifically for NBA, ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...NCAA ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...NCAA f-ball ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...For now I’m looking specifically for NBA, ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...this? For now I’m looking specifically for NBA, ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...NCAA ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...NCAA f-ball ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...NCAA f-ball and ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...also ...NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...am also ...NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...am also ...in ...NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...NCAA f-ball and ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...also ...NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...am also ...NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...am also ...in ...NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...am also interested in ...NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in ...NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in ...NFL, ...NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, ...NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, ...am also interested in ...NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in ...NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in ...NFL, ...NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, ...NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding ...team’s performance ...direction. Does anyone know of an API that tracks this? For now I’m looking specifically for NBA, but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
# ...
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking ...for ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now ...looking ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking specifically for ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking ...for ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now I’m looking ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now ...looking ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? For now ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? ...now ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone ...of an API that ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? ...now ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks this? ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that tracks ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone know of an API that ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does anyone ...of an API that ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does ...of an API that ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. ...of an API that ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...of an API that ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...of an API ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...of an ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. Does ...of an API that ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or direction. ...of an API that ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...of an API that ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...of an API ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...of an ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...of ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in MLB, NFL, and ...f-ball and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in MLB, NFL, and ...and b-ball.'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in MLB, NFL, and ...b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...of ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in MLB, NFL, and NCAA f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in MLB, NFL, and ...f-ball and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in MLB, NFL, and ...and b-ball.', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in MLB, NFL, and ...b-ball.']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in MLB, NFL, and ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in MLB, NFL, ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in ...NFL, ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also ...in ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in MLB, NFL, and ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in MLB, NFL, ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in ...NFL, ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also interested in ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also ...in ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but ...'
#  'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  'I’m looking for datasets ...api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am also ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but am ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...but ...', 'I’m looking for datasets or api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', 'I’m looking for datasets ...api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['I’m ...for datasets ...api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...for datasets ...api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...for ...api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...api source that quantifies ...base, or preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['I’m ...for datasets ...api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', '...for datasets ...api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', '...for ...api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', '...api source that quantifies fan base, or preferably, bettors’ sentiment regarding a team’s performance or ...', '...api source that quantifies ...base, or preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['...api source that quantifies ...or preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...api source that quantifies ...preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...api source that ...preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...api source ...preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...source ...preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['...api source that quantifies ...or preferably, bettors’ sentiment regarding a team’s performance or ...', '...api source that quantifies ...preferably, bettors’ sentiment regarding a team’s performance or ...', '...api source that ...preferably, bettors’ sentiment regarding a team’s performance or ...', '...api source ...preferably, bettors’ sentiment regarding a team’s performance or ...', '...source ...preferably, bettors’ sentiment regarding a team’s performance or ...']
# ['...preferably, bettors’ sentiment regarding a team’s performance or ...'
#  '...preferably, bettors’ ...regarding a team’s performance or ...'
#  '...preferably, bettors’ ...a team’s performance or ...'
#  '...preferably, ...a team’s performance or ...'
#  '...a team’s performance or ...']
# ['...preferably, bettors’ sentiment regarding a team’s performance or ...', '...preferably, bettors’ ...regarding a team’s performance or ...', '...preferably, bettors’ ...a team’s performance or ...', '...preferably, ...a team’s performance or ...', '...a team’s performance or ...']
# ['...a team’s ...or ...' '...team’s ...or ...' '...or ...' '...']
# ['...a team’s ...or ...', '...team’s ...or ...', '...or ...', '...']

# %%
shap.plots.text(shap_values)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_bmywjjsjcnlitytoymxk = '_tp_bmywjjsjcnlitytoymxk_output_0';
#     document._zoom_bmywjjsjcnlitytoymxk = undefined;
#     function _output_onclick_bmywjjsjcnlitytoymxk(i) {
#         var next_id = undefined;
#
#         if (document._zoom_bmywjjsjcnlitytoymxk !== undefined) {
#             document.getElementById(document._zoom_bmywjjsjcnlitytoymxk+ '_zoom').style.display = 'none';
#
#             if (document._zoom_bmywjjsjcnlitytoymxk === '_tp_bmywjjsjcnlitytoymxk_output_' + i) {
#                 document.getElementById(document._zoom_bmywjjsjcnlitytoymxk).style.display = 'block';
#                 document.getElementById(document._zoom_bmywjjsjcnlitytoymxk+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_bmywjjsjcnlitytoymxk).style.display = 'none';
#                 document.getElementById(document._zoom_bmywjjsjcnlitytoymxk+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_bmywjjsjcnlitytoymxk !== '_tp_bmywjjsjcnlitytoymxk_output_' + i) {
#             next_id = '_tp_bmywjjsjcnlitytoymxk_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_bmywjjsjcnlitytoymxk = next_id;
#     }
#     function _output_onmouseover_bmywjjsjcnlitytoymxk(i, el) {
#         if (document._zoom_bmywjjsjcnlitytoymxk !== undefined) { return; }
#         if (document._hover_bmywjjsjcnlitytoymxk !== undefined) {
#             document.getElementById(document._hover_bmywjjsjcnlitytoymxk + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_bmywjjsjcnlitytoymxk).style.display = 'none';
#         }
#         document.getElementById('_tp_bmywjjsjcnlitytoymxk_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_bmywjjsjcnlitytoymxk = '_tp_bmywjjsjcnlitytoymxk_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(255.0, 13.0, 87.0, 0.00677361853832443); border-radius: 3px; padding: 0px" id="_tp_bmywjjsjcnlitytoymxk_output_0_name"
#     onclick="_output_onclick_bmywjjsjcnlitytoymxk(0)"
#     onmouseover="_output_onmouseover_bmywjjsjcnlitytoymxk(0, this);">LanguageTechnology</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_bmywjjsjcnlitytoymxk_output_1_name"
#     onclick="_output_onclick_bmywjjsjcnlitytoymxk(1)"
#     onmouseover="_output_onmouseover_bmywjjsjcnlitytoymxk(1, this);">datasets</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.00677361853832443); border-radius: 3px; padding: 0px" id="_tp_bmywjjsjcnlitytoymxk_output_2_name"
#     onclick="_output_onclick_bmywjjsjcnlitytoymxk(2)"
#     onmouseover="_output_onmouseover_bmywjjsjcnlitytoymxk(2, this);">dataengineering</div><br><br><div id='_tp_bmywjjsjcnlitytoymxk_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="48.2035097536617%" y1="33" x2="48.2035097536617%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="48.2035097536617%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.5</text><line x1="33.09559504270623%" y1="33" x2="33.09559504270623%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="33.09559504270623%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.3</text><line x1="17.987680331750763%" y1="33" x2="17.987680331750763%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="17.987680331750763%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.1</text><line x1="63.31142446461715%" y1="33" x2="63.31142446461715%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="63.31142446461715%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.7</text><line x1="78.41933917557263%" y1="33" x2="78.41933917557263%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="78.41933917557263%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.9</text><line x1="35.9054117281699%" y1="33" x2="35.9054117281699%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="35.9054117281699%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.337197</text><text x="35.9054117281699%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0.337197</text><text x="35.9054117281699%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="11.572068450132583%" y1="33" x2="11.572068450132583%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="11.572068450132583%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">0.0150695</text><text x="11.572068450132583%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">0.0150695</text><text x="11.572068450132583%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">LanguageTechnology</tspan>(inputs)</text><rect x="4.323672425662298%" width="7.248396024470284%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="9.918603824397419%" x2="11.572068450132583%" y1="60" y2="60" id="_fb_wtambrmmldmfumewgsuv_ind_39" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="10.745336137265001%" y="71" font-size="12px" id="_fs_wtambrmmldmfumewgsuv_ind_39" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">0.022</text><svg x="9.918603824397419%" y="40" height="20" width="1.6534646257351646%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">also</text>  </svg></svg><line x1="8.855418890840605%" x2="9.918603824397419%" y1="60" y2="60" id="_fb_wtambrmmldmfumewgsuv_ind_30" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="9.387011357619013%" y="71" font-size="12px" id="_fs_wtambrmmldmfumewgsuv_ind_30" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middl ...

# %% [markdown]
# # Gendered Language

# %%
import spacy

textcat_spacy = spacy.load(".\model-best\model-best")
tokenizer_spacy = spacy.tokenizer.Tokenizer(textcat_spacy.vocab)
classes = list(textcat_spacy.get_pipe("textcat").labels)

# Define a function to predict
def predict(texts):
    # convert texts to bare strings
    texts = [str(text) for text in texts]
    results = []
    for doc in textcat_spacy.pipe(texts):
        # results.append([{'label': cat, 'score': doc.cats[cat]} for cat in doc.cats])
        results.append([doc.cats[cat] for cat in classes])
    return results

# Create a function to create a transformers-like tokenizer to match shap's expectations
def tok_wrapper(text, return_offsets_mapping=False):
    doc = tokenizer_spacy(text)
    out = {"input_ids": [tok.norm for tok in doc]}
    if return_offsets_mapping:
        out["offset_mapping"] = [(tok.idx, tok.idx + len(tok)) for tok in doc]
    return out
